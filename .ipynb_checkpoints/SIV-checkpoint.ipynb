# %%
import sys
import os

# Add the path to starlink-grpc-tools-main to the system path
sys.path.append(os.path.abspath('E:\SatInView/starlink-grpc-tools-main'))
import math
import starlink_grpc
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np
import time

def calculate_azimuth_elevation(image_width, image_height):
    # Ensure the image is square
    assert image_width == image_height, "Image must be square"
    
    center_x = (image_width // 2)-2
    center_y = (image_height // 2)-13
    
    azimuth_elevation_map = []

    for y in range(image_height):
        row = []
        for x in range(image_width):
            # Convert pixel (x, y) to Cartesian coordinates with the center as (0, 0)
            dx = x - center_x
            dy = center_y - y  # Adjust dy to invert y-axis

            # Calculate azimuth
            azimuth = (math.degrees(math.atan2(dx, -dy)) + 360) % 360
            
            # Calculate elevation
            distance_from_center = math.sqrt(dx**2 + dy**2)
            max_distance = center_x  # max distance in pixels
            elevation = 90 * (1 - (distance_from_center / max_distance))  # Minimum elevation is 10 degrees

            if distance_from_center > max_distance:
                # Pixels outside the circle represent "no data"
                row.append((None, None))
            else:
                row.append((azimuth, elevation))
        
        azimuth_elevation_map.append(row)
    
    return azimuth_elevation_map

def find_closest_white_pixel(snr_data, azimuth_elevation_map):
    center_x = len(snr_data[0]) // 2
    center_y = len(snr_data) // 2
    closest_distance = float('inf')
    closest_azimuth = None
    closest_elevation = None
    closest_x = None
    closest_y = None

    for y in range(len(snr_data)):
        for x in range(len(snr_data[y])):
            if snr_data[y][x] == 1:  # Check if the pixel is white
                dx = x - center_x
                dy = y - center_y  # Do not invert dy for distance calculation
                distance = math.sqrt(dx**2 + dy**2)

                if distance < closest_distance:
                    closest_distance = distance
                    closest_azimuth, closest_elevation = azimuth_elevation_map[y][x]
                    closest_x = x
                    closest_y = y

    return closest_azimuth, closest_elevation, closest_x, closest_y,closest_distance


# Assuming this function gets snr_data from the dish
context = starlink_grpc.ChannelContext(target="192.168.100.1:9200")  # Example target
try:
    starlink_grpc.reset_obstruction_map(context)
    time.sleep(15)
    snr_data1 = starlink_grpc.obstruction_map(context)
    current_utc_time = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
    print(f"Current UTC time: {current_utc_time}")
    time.sleep(2)
    snr_data2 = starlink_grpc.obstruction_map(context)
    snr_data1_array = np.array(snr_data1, dtype=int)
    snr_data1_array[snr_data1_array == -1] = 0

    snr_data2_array = np.array(snr_data2, dtype=int)
    snr_data2_array[snr_data2_array == -1] = 0

    # Perform bitwise XOR operation
    snr_data = np.bitwise_xor(snr_data1_array, snr_data2_array).tolist() 
    current_utc_time = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
    print(f"Current UTC time: {current_utc_time}")
except starlink_grpc.GrpcError as e:
    print("Failed getting obstruction map data:", str(e))
    # return

if not snr_data or not snr_data[0]:
    print("Invalid SNR map data: Zero-length")
    # return

image_width = len(snr_data[0])
image_height = len(snr_data)
print(len(snr_data[0]) // 2)
print(len(snr_data) // 2)
azimuth_elevation_map = calculate_azimuth_elevation(image_width, image_height)
closest_azimuth, closest_elevation, closest_x, closest_y,closest_distance = find_closest_white_pixel(snr_data, azimuth_elevation_map)

current_utc_time = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")

if closest_azimuth is not None and closest_elevation is not None:
    print(f"closest_distance: {closest_distance}")
    print(f"Closest white pixel coordinates: (x={closest_x}, y={closest_y})")
    print(f"Closest white pixel azimuth: {closest_azimuth}, elevation: {closest_elevation}, Zenith: {90-closest_elevation}")
else:
    print(f"Current UTC time: {current_utc_time}")
    print("No white pixel found.")

# Plotting the image
plt.figure(figsize=(8, 8))
plt.imshow(snr_data, cmap='gray', origin='lower')  # Adjust origin to 'upper' to correct orientation

if closest_x is not None and closest_y is not None:
    plt.scatter([closest_x], [closest_y], color='red', marker='o', s=2)
    plt.text(closest_x, closest_y, f'Az: {closest_azimuth:.2f}, El: {90-closest_elevation:.2f}', 
             color='red', fontsize=12, ha='right', va='bottom')

plt.title(f'Starlink Obstruction Map\n{current_utc_time}')
# plt.xlabel('Azimuth (degrees)')
# plt.ylabel('Elevation (degrees)')
plt.show()
# Out:
# Current UTC time: 2024-05-24 20:37:59
# Current UTC time: 2024-05-24 20:38:01
# 61
# 61
# closest_distance: 29.832867780352597
# Closest white pixel coordinates: (x=32, y=54)
# Closest white pixel azimuth: 282.5288077091515, elevation: 47.8088643479817, Zenith: 42.1911356520183

# %%
from skyfield.api import load, wgs84, Topos
import matplotlib.pyplot as plt
import numpy as np
from datetime import timedelta
import math

def load_data():
    stations_url = 'https://celestrak.org/NORAD/elements/gp.php?GROUP=starlink&FORMAT=tle'
    satellites = load.tle_file(stations_url)
    print('Loaded', len(satellites), 'satellites')
    return satellites

def set_observation_time_now(year, month, day, hour, minute, second):
    ts = load.timescale()
    return ts.now()- timedelta(seconds=1)
def set_observation_time(year, month, day, hour, minute, second):
    ts = load.timescale()
    return ts.utc(year, month, day, hour, minute, second)

def calculate_satellite_positions(satellites, observer_location, observation_time):
    locations = []
    sats = []
    min_elevation = 20
    for satellite in satellites:
        difference = satellite - observer_location
        topocentric = difference.at(observation_time)
        alt, az, distance = topocentric.altaz()
        if alt.degrees > min_elevation:
            loc = [(90 - alt.degrees, np.radians(az.degrees))]
            locations.append(loc)
            sats.append(satellite)
            print(f"{satellite} at Azimuth: {az.degrees}°, Altitude: {alt.degrees}°, Distance: {distance.km} km")
    return locations, sats

def rotate_points(x, y, angle):
    x_rot = x * np.cos(angle) - y * np.sin(angle)
    y_rot = x * np.sin(angle) + y * np.cos(angle)
    return x_rot, y_rot

def draw_fov(tilt_deg, rotation_deg, locations, sats, observation_time, observer_location):
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'}, figsize=(16, 16))

    # Plot settings
    ax.set_ylim(0, 90)
    ax.set_yticks(np.arange(0, 91, 10))
    ax.set_theta_zero_location("N")
    ax.set_theta_direction(-1)
    ax.grid(True)

    zenith_legend = plt.Line2D([0], [0], color='gray', linestyle='-', linewidth=1, label='Zenith Lines')
    azimuth_legend = plt.Line2D([0], [0], color='black', linestyle='-', linewidth=1, label='Azimuth')
    FOV = plt.Line2D([0], [0], color='red', linestyle='-', linewidth=2, label='FOV')
    Axis = plt.Line2D([0], [0], color='red', linestyle='--', linewidth=1, label='FOV axis')
    ax.add_artist(zenith_legend)
    ax.add_artist(azimuth_legend)
    ax.add_artist(FOV)
    ax.add_artist(Axis)

    # FOV ellipse
    base_radius = 60
    center_shift = tilt_deg
    x_radius = base_radius
    y_radius = math.sqrt(base_radius**2 - tilt_deg**2)

    theta = np.linspace(0, 2 * np.pi, 300)
    x = x_radius * np.cos(theta) + center_shift
    y = y_radius * np.sin(theta)
    r = np.sqrt(x**2 + y**2)
    angles = np.arctan2(y, x) + np.deg2rad(rotation_deg)
    ax.plot(angles, r, 'r')

    # Plot major and minor axes
    major_axis_x = np.array([center_shift + x_radius, center_shift - x_radius])
    major_axis_y = np.array([0, 0])
    minor_axis_x = np.array([center_shift, center_shift])
    minor_axis_y = np.array([y_radius, -y_radius])
    major_axis_x_rot, major_axis_y_rot = rotate_points(major_axis_x, major_axis_y, np.deg2rad(rotation_deg))
    minor_axis_x_rot, minor_axis_y_rot = rotate_points(minor_axis_x, minor_axis_y, np.deg2rad(rotation_deg))
    ax.plot(np.arctan2(major_axis_y_rot, major_axis_x_rot), np.sqrt(major_axis_x_rot**2 + major_axis_y_rot**2), 'red', linestyle='--', linewidth=1)
    ax.plot(np.arctan2(minor_axis_y_rot, minor_axis_x_rot), np.sqrt(minor_axis_x_rot**2 + minor_axis_y_rot**2), 'red', linestyle='--', linewidth=1)

    inside_fov = []

    # Plot satellites
    for loc, sat in zip(locations, sats):
        loc = np.array(loc)
        r = loc[:, 0]
        angle = loc[:, 1]
        inside = False
        for r_i, angle_i in zip(r, angle):
            x_point = r_i * np.cos(angle_i)
            y_point = r_i * np.sin(angle_i)
            x_point_rot, y_point_rot = rotate_points(x_point, y_point, -np.deg2rad(rotation_deg))
            x_point_rot -= center_shift
            if (x_point_rot**2 / x_radius**2) + (y_point_rot**2 / y_radius**2) <= 1:
                inside = True
                break
        if inside:
            ax.scatter(angle, r, color="g", label="Inside FOV")
            inside_fov.append(sat.name)
        else:
            ax.scatter(angle, r, color="b", label="Outside FOV")
        ax.annotate(sat.name, xy=(angle, r), xytext=(0, 5), textcoords='offset points', ha='center', va='bottom', fontsize=6, bbox=dict(boxstyle='round,pad=0.5', edgecolor='none', facecolor='none', alpha=0.6))

    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), loc='upper right')
    
    # Format the observation time
    observation_time_str = observation_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')
    latitude_str = f"{abs(observer_location.latitude.degrees)}° {'N' if observer_location.latitude.degrees >= 0 else 'S'}"
    longitude_str = f"{abs(observer_location.longitude.degrees)}° {'E' if observer_location.longitude.degrees >= 0 else 'W'}"
    observer_location_str = f"{latitude_str}, {longitude_str}"
    ax.set_title(f'{tilt_deg}° Tilt, {rotation_deg}° Rotation\nObservation Time: {observation_time_str}\nObserver Location: {observer_location_str}', va='bottom')
    
    ax.scatter(np.deg2rad(closest_azimuth), 90-closest_elevation, color='red', marker='o', s=150)
    plt.show()
    print("Satellites inside the FOV:", inside_fov)
    print("what", closest_azimuth)

if __name__ == "__main__":
    satellites = load_data()
    initial_time = set_observation_time(2024, 5, 24, 22, 10, 45 )
    observer_location = wgs84.latlon(latitude_degrees=48.461195499999974, longitude_degrees=-123.31172833333332, elevation_m=73)
    locations, sats = calculate_satellite_positions(satellites, observer_location, initial_time)
    draw_fov(27,-1.3, locations, sats, initial_time, observer_location)
    # draw_fov(10, 45, locations, sats, initial_time, observer_location)-
    # draw_fov(20, 90, locations, sats, initial_time, observer_location)
    # draw_fov(30, 315, locations, sats, initial_time, observer_location)
# Out:
# Loaded 6010 satellites
# STARLINK-1122 catalog #44949 epoch 2024-05-24 01:07:51 UTC at Azimuth: 10.72243716393881°, Altitude: 52.684897603785764°, Distance: 679.1392374380367 km
# STARLINK-1080 catalog #44961 epoch 2024-05-23 23:29:40 UTC at Azimuth: 340.93121406848076°, Altitude: 40.84762135106341°, Distance: 804.0145865948102 km
# STARLINK-1170 catalog #45073 epoch 2024-05-24 12:08:40 UTC at Azimuth: 280.72284314129985°, Altitude: 28.582251137677773°, Distance: 1029.9644502022834 km
# STARLINK-1624 catalog #46130 epoch 2024-05-23 23:23:02 UTC at Azimuth: 107.96263199189853°, Altitude: 48.88180589066851°, Distance: 710.8893801102389 km
# STARLINK-1598 catalog #46160 epoch 2024-05-23 20:14:37 UTC at Azimuth: 66.58652589160207°, Altitude: 27.23575561509151°, Distance: 1064.783184512091 km
# STARLINK-1721 catalog #46332 epoch 2024-05-24 01:33:01 UTC at Azimuth: 52.28688777261072°, Altitude: 20.424423521611775°, Distance: 1073.0075298430975 km
# STARLINK-1646 catalog #46351 epoch 2024-05-24 02:50:03 UTC at Azimuth: 188.52861357785113°, Altitude: 25.625656493716438°, Distance: 1105.5373734296768 km
# STARLINK-1688 catalog #46371 epoch 2024-05-24 14:00:01 UTC at Azimuth: 72.6881743826736°, Altitude: 21.375464653121536°, Distance: 886.9485166033894 km
# STARLINK-1769 catalog #46382 epoch 2024-05-24 01:09:52 UTC at Azimuth: 286.68487324123°, Altitude: 51.338515035589566°, Distance: 690.1317767742499 km
# STARLINK-1911 catalog #46749 epoch 2024-05-24 01:05:52 UTC at Azimuth: 45.053396714955284°, Altitude: 31.21314889188959°, Distance: 969.8913299557021 km
# STARLINK-1883 catalog #46785 epoch 2024-05-23 20:20:35 UTC at Azimuth: 304.818516675151°, Altitude: 28.48264724794092°, Distance: 1033.2519973450198 km
# STARLINK-1863 catalog #47150 epoch 2024-05-23 23:29:01 UTC at Azimuth: 303.823801548594°, Altitude: 20.879106850272073°, Distance: 1265.6815949003621 km
# STARLINK-1864 catalog #47151 epoch 2024-05-23 20:16:37 UTC at Azimuth: 32.29587426770519°, Altitude: 40.04118696883764°, Distance: 815.088892648297 km
# STARLINK-2012 catalog #47635 epoch 2024-05-24 02:47:23 UTC at Azimuth: 254.18356868014624°, Altitude: 29.536173763872902°, Distance: 1006.5689380386982 km
# STARLINK-2401 catalog #47818 epoch 2024-05-24 12:04:47 UTC at Azimuth: 196.94444966559882°, Altitude: 31.458948535841618°, Distance: 958.0027893279615 km
# STARLINK-2329 catalog #47873 epoch 2024-05-23 21:46:50 UTC at Azimuth: 241.09701345168125°, Altitude: 40.87867463013926°, Distance: 801.369392257856 km
# STARLINK-2336 catalog #47879 epoch 2024-05-23 20:15:56 UTC at Azimuth: 315.7368249713932°, Altitude: 37.49226054422951°, Distance: 853.46576033075 km
# STARLINK-2339 catalog #47881 epoch 2024-05-23 18:38:25 UTC at Azimuth: 3.809413276301526°, Altitude: 68.79866042003748°, Distance: 588.4721182623443 km
# STARLINK-2308 catalog #47985 epoch 2024-05-24 12:05:23 UTC at Azimuth: 124.50481911743778°, Altitude: 25.26808716006048°, Distance: 1117.0991456602542 km
# STARLINK-2589 catalog #48371 epoch 2024-05-24 02:48:02 UTC at Azimuth: 160.18439313871022°, Altitude: 48.17962467795227°, Distance: 716.9523775794252 km
# STARLINK-2575 catalog #48396 epoch 2024-05-24 02:44:03 UTC at Azimuth: 66.73101903532803°, Altitude: 25.398397930164688°, Distance: 1115.8617961353998 km
# STARLINK-3298 catalog #50165 epoch 2024-05-24 12:05:31 UTC at Azimuth: 177.371613150482°, Altitude: 30.54230053517154°, Distance: 968.6082143628793 km
# STARLINK-3374 catalog #51112 epoch 2024-05-23 20:19:39 UTC at Azimuth: 307.5363077820608°, Altitude: 24.485002147998195°, Distance: 1130.5504554809243 km
# STARLINK-3389 catalog #51124 epoch 2024-05-23 23:27:43 UTC at Azimuth: 69.66537699830312°, Altitude: 20.139766913598432°, Distance: 1278.7385708997435 km
# STARLINK-3396 catalog #51129 epoch 2024-05-23 23:29:06 UTC at Azimuth: 45.47034759608497°, Altitude: 35.75138099343185°, Distance: 871.3566890624458 km
# STARLINK-3359 catalog #51148 epoch 2024-05-23 20:22:20 UTC at Azimuth: 314.71369787904774°, Altitude: 31.373247873411458°, Distance: 955.0187134216856 km
# STARLINK-3189 catalog #51464 epoch 2024-05-23 18:38:55 UTC at Azimuth: 100.72986298650413°, Altitude: 34.475238667193146°, Distance: 891.8607272982417 km
# STARLINK-3449 catalog #51745 epoch 2024-05-23 20:24:54 UTC at Azimuth: 289.0212618518218°, Altitude: 23.08227364037496°, Distance: 1173.2225674627798 km
# STARLINK-3626 catalog #51792 epoch 2024-05-24 02:47:45 UTC at Azimuth: 84.011369719256°, Altitude: 33.46459048339271°, Distance: 911.3622593265526 km
# STARLINK-3604 catalog #51815 epoch 2024-05-24 01:09:44 UTC at Azimuth: 35.7923032694735°, Altitude: 43.44365515699872°, Distance: 760.1912630314602 km
# STARLINK-3565 catalog #51886 epoch 2024-05-24 04:27:07 UTC at Azimuth: 171.3916345418474°, Altitude: 27.258031096755737°, Distance: 1047.4950347112037 km
# STARLINK-4019 catalog #52598 epoch 2024-05-23 20:16:17 UTC at Azimuth: 52.13120349069903°, Altitude: 57.065361792606936°, Distance: 638.6183813939094 km
# STARLINK-3982 catalog #52614 epoch 2024-05-23 18:40:14 UTC at Azimuth: 280.9376763349615°, Altitude: 39.45394008253131°, Distance: 812.7452417991793 km
# STARLINK-4360 catalog #53482 epoch 2024-05-24 05:35:18 UTC at Azimuth: 145.81165904380097°, Altitude: 54.69187784855879°, Distance: 685.6801483455746 km
# STARLINK-4387 catalog #53490 epoch 2024-05-24 05:37:58 UTC at Azimuth: 25.12342302105888°, Altitude: 27.77126185005301°, Distance: 1087.3332924269396 km
# STARLINK-4722 catalog #53775 epoch 2024-05-23 20:17:39 UTC at Azimuth: 295.6130482370471°, Altitude: 21.384868446897908°, Distance: 1232.4790162598779 km
# STARLINK-4760 catalog #53828 epoch 2024-05-23 21:54:18 UTC at Azimuth: 46.63431059980622°, Altitude: 31.617490822317723°, Distance: 949.6862675861064 km
# STARLINK-4777 catalog #53847 epoch 2024-05-23 20:20:15 UTC at Azimuth: 311.2553282335632°, Altitude: 26.485255665721304°, Distance: 1073.247868322679 km
# STARLINK-4797 catalog #53852 epoch 2024-05-23 20:18:16 UTC at Azimuth: 335.31252367332°, Altitude: 45.27985448268987°, Distance: 739.6737956963157 km
# STARLINK-4732 catalog #53870 epoch 2024-05-23 18:38:14 UTC at Azimuth: 218.2419032975253°, Altitude: 51.74883195886337°, Distance: 676.2143540830102 km
# STARLINK-5031 catalog #53889 epoch 2024-05-24 01:07:46 UTC at Azimuth: 52.21098454616061°, Altitude: 24.067029958966454°, Distance: 1143.5055127405003 km
# STARLINK-5048 catalog #53911 epoch 2024-05-23 20:22:56 UTC at Azimuth: 316.51984950877295°, Altitude: 35.29252427610616°, Distance: 879.1525991848515 km
# STARLINK-5158 catalog #54055 epoch 2024-05-24 02:51:06 UTC at Azimuth: 234.59635326541243°, Altitude: 20.578815987865987°, Distance: 1257.6107550816887 km
# STARLINK-5160 catalog #54080 epoch 2024-05-24 12:21:26 UTC at Azimuth: 248.67391408135504°, Altitude: 39.29727690364632°, Distance: 813.9107281640725 km
# STARLINK-5183 catalog #54084 epoch 2024-05-23 20:25:35 UTC at Azimuth: 313.50284262206304°, Altitude: 67.98555272333444°, Distance: 583.6038405940943 km
# STARLINK-5248 catalog #54174 epoch 2024-05-23 20:20:53 UTC at Azimuth: 5.061820284630394°, Altitude: 41.1615932979552°, Distance: 789.476524436303 km
# STARLINK-5268 catalog #54192 epoch 2024-05-23 18:52:47 UTC at Azimuth: 132.11184444120374°, Altitude: 42.87140505383444°, Distance: 765.6918210929293 km
# STARLINK-5033 catalog #55412 epoch 2024-05-24 11:59:12 UTC at Azimuth: 205.45661885075177°, Altitude: 60.108648490234806°, Distance: 659.7542814575354 km
# STARLINK-5616 catalog #55417 epoch 2024-05-24 11:58:57 UTC at Azimuth: 192.74537826365605°, Altitude: 54.5620348131172°, Distance: 697.0281473520172 km
# STARLINK-5081 catalog #55759 epoch 2024-05-24 12:19:21 UTC at Azimuth: 64.46225572829039°, Altitude: 45.98079027111691°, Distance: 778.8451620394845 km
# STARLINK-5811 catalog #55787 epoch 2024-05-24 04:18:20 UTC at Azimuth: 294.43111000804936°, Altitude: 25.976238371795596°, Distance: 1150.9281098688175 km
# STARLINK-5956 catalog #55994 epoch 2024-05-23 23:29:11 UTC at Azimuth: 220.42871248788524°, Altitude: 28.544072334560582°, Distance: 1049.8809651231895 km
# STARLINK-5783 catalog #56022 epoch 2024-05-23 21:49:03 UTC at Azimuth: 161.09584083817407°, Altitude: 36.05218597973716°, Distance: 893.5374376696576 km
# STARLINK-5770 catalog #56026 epoch 2024-05-24 00:58:53 UTC at Azimuth: 126.88348403563622°, Altitude: 20.238830818946347°, Distance: 1310.348622147093 km
# STARLINK-6175 catalog #56882 epoch 2024-05-24 02:44:38 UTC at Azimuth: 180.0331867248484°, Altitude: 20.938805391110257°, Distance: 1281.4435932707584 km
# STARLINK-5971 catalog #56917 epoch 2024-05-23 01:08:33 UTC at Azimuth: 132.0871116464959°, Altitude: 26.54314829762013°, Distance: 1101.8706000965637 km
# STARLINK-6230 catalog #57228 epoch 2024-05-23 23:23:35 UTC at Azimuth: 205.46962133378827°, Altitude: 31.310999571029296°, Distance: 985.0934003764369 km
# STARLINK-30278 catalog #57668 epoch 2024-05-23 20:36:54 UTC at Azimuth: 27.129066079708906°, Altitude: 35.30413491226309°, Distance: 806.542582869329 km
# STARLINK-30316 catalog #57673 epoch 2024-05-24 01:23:59 UTC at Azimuth: 336.6750993497801°, Altitude: 37.367891539470264°, Distance: 759.6143123376916 km
# STARLINK-30321 catalog #57679 epoch 2024-05-24 01:23:31 UTC at Azimuth: 359.5705522320528°, Altitude: 39.130020244166445°, Distance: 735.4854352302475 km
# STARLINK-30531 catalog #57998 epoch 2024-05-24 02:41:43 UTC at Azimuth: 178.64261222247853°, Altitude: 32.18116755279734°, Distance: 967.0803499487789 km
# STARLINK-30541 catalog #58057 epoch 2024-05-24 00:57:43 UTC at Azimuth: 158.4821780593703°, Altitude: 26.18857258844781°, Distance: 1110.9053097616038 km
# STARLINK-30583 catalog #58086 epoch 2024-05-24 02:44:06 UTC at Azimuth: 177.05922330332953°, Altitude: 22.91715267521922°, Distance: 1211.7052267615015 km
# STARLINK-30353 catalog #58113 epoch 2024-05-24 12:13:22 UTC at Azimuth: 143.4122776669803°, Altitude: 24.57207101936184°, Distance: 1017.5143079756095 km
# STARLINK-30493 catalog #58116 epoch 2024-05-23 18:57:47 UTC at Azimuth: 149.52662591122865°, Altitude: 31.294054738420304°, Distance: 858.358141971799 km
# STARLINK-30803 catalog #58157 epoch 2024-05-24 01:26:38 UTC at Azimuth: 293.7295327147952°, Altitude: 26.7724247172541°, Distance: 962.2195558513912 km
# STARLINK-30829 catalog #58158 epoch 2024-05-23 20:44:34 UTC at Azimuth: 287.00645079207646°, Altitude: 21.39839012990176°, Distance: 1117.5574738824198 km
# STARLINK-30902 catalog #58421 epoch 2024-05-23 20:14:25 UTC at Azimuth: 125.18466470169712°, Altitude: 25.169831282252566°, Distance: 1141.9940076227854 km
# STARLINK-30976 catalog #58447 epoch 2024-05-23 23:26:18 UTC at Azimuth: 217.06322784222743°, Altitude: 33.56066983145528°, Distance: 940.0937381937638 km
# STARLINK-30980 catalog #58476 epoch 2024-05-24 01:04:01 UTC at Azimuth: 126.9098329708971°, Altitude: 24.961891348947145°, Distance: 1148.0395687742607 km
# STARLINK-31097 catalog #58718 epoch 2024-05-23 20:09:25 UTC at Azimuth: 215.23237728432494°, Altitude: 50.272486466906855°, Distance: 703.5641501209251 km
# STARLINK-31196 catalog #58868 epoch 2024-05-23 20:34:48 UTC at Azimuth: 209.99716772068507°, Altitude: 22.705272427189716°, Distance: 1084.363436747382 km
# STARLINK-31586 catalog #59205 epoch 2024-05-24 12:21:37 UTC at Azimuth: 280.9733107584612°, Altitude: 25.60920057108334°, Distance: 927.6875576254756 km
# STARLINK-31523 catalog #59220 epoch 2024-05-23 17:39:23 UTC at Azimuth: 272.724131626807°, Altitude: 34.798050161983575°, Distance: 744.1574889897098 km
# STARLINK-31598 catalog #59263 epoch 2024-05-23 19:14:08 UTC at Azimuth: 63.23958675205057°, Altitude: 37.539941136258385°, Distance: 704.8844884115388 km
# STARLINK-31477 catalog #59314 epoch 2024-05-23 19:19:09 UTC at Azimuth: 143.5007855140027°, Altitude: 26.95757182023569°, Distance: 887.3021240593102 km
# STARLINK-31501 catalog #59359 epoch 2024-05-24 14:00:01 UTC at Azimuth: 189.21337575689°, Altitude: 21.499642721139384°, Distance: 1024.8533947073108 km
# Satellites inside the FOV: ['STARLINK-1122', 'STARLINK-1080', 'STARLINK-1624', 'STARLINK-1769', 'STARLINK-1911', 'STARLINK-1883', 'STARLINK-1864', 'STARLINK-2336', 'STARLINK-2339', 'STARLINK-3374', 'STARLINK-3396', 'STARLINK-3359', 'STARLINK-3604', 'STARLINK-4019', 'STARLINK-3982', 'STARLINK-4387', 'STARLINK-4760', 'STARLINK-4777', 'STARLINK-4797', 'STARLINK-5048', 'STARLINK-5183', 'STARLINK-5248', 'STARLINK-5033', 'STARLINK-5081', 'STARLINK-30278', 'STARLINK-30316', 'STARLINK-30321', 'STARLINK-31598']
# what 343.0083992954603

# %%
from skyfield.api import load, wgs84
import matplotlib.pyplot as plt
import numpy as np
from datetime import timedelta
import math

def load_data():
    stations_url = 'https://celestrak.org/NORAD/elements/gp.php?GROUP=starlink&FORMAT=tle'
    satellites = load.tle_file(stations_url)
    print('Loaded', len(satellites), 'satellites')
    return satellites

def set_observation_time_now():
    ts = load.timescale()
    return ts.now() - timedelta(seconds=1)

def set_observation_time(year, month, day, hour, minute, second):
    ts = load.timescale()
    return ts.utc(year, month, day, hour, minute, second)

def calculate_satellite_positions_over_time(satellites, observer_location, start_time, interval_seconds):
    positions_over_time = {}
    min_elevation = 20
    for satellite in satellites:
        positions = []
        altitudes = []
        for second in range(interval_seconds + 1):
            current_time = start_time + timedelta(seconds=second)
            difference = satellite - observer_location
            topocentric = difference.at(current_time)
            alt, az, distance = topocentric.altaz()
            positions.append((90 - alt.degrees, np.radians(az.degrees)))
            altitudes.append(alt.degrees)
        if any(alt > min_elevation for alt in altitudes):
            positions_over_time[satellite.name] = positions
    return positions_over_time

def rotate_points(x, y, angle):
    x_rot = x * np.cos(angle) - y * np.sin(angle)
    y_rot = x * np.sin(angle) + y * np.cos(angle)
    return x_rot, y_rot

def draw_fov(tilt_deg, rotation_deg, positions_over_time, observation_time, observer_location):
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'}, figsize=(16, 16))

    # Plot settings
    ax.set_ylim(0, 90)
    ax.set_yticks(np.arange(0, 91, 10))
    ax.set_theta_zero_location("N")
    ax.set_theta_direction(-1)
    ax.grid(True)

    zenith_legend = plt.Line2D([0], [0], color='gray', linestyle='-', linewidth=1, label='Zenith Lines')
    azimuth_legend = plt.Line2D([0], [0], color='black', linestyle='-', linewidth=1, label='Azimuth')
    FOV = plt.Line2D([0], [0], color='red', linestyle='-', linewidth=2, label='FOV')
    Axis = plt.Line2D([0], [0], color='red', linestyle='--', linewidth=1, label='FOV axis')
    ax.add_artist(zenith_legend)
    ax.add_artist(azimuth_legend)
    ax.add_artist(FOV)
    ax.add_artist(Axis)

    # FOV ellipse
    base_radius = 60
    center_shift = tilt_deg
    x_radius = base_radius
    y_radius = math.sqrt(base_radius**2 - tilt_deg**2)

    theta = np.linspace(0, 2 * np.pi, 300)
    x = x_radius * np.cos(theta) + center_shift
    y = y_radius * np.sin(theta)
    r = np.sqrt(x**2 + y**2)
    angles = np.arctan2(y, x) + np.deg2rad(rotation_deg)
    ax.plot(angles, r, 'r')

    # Plot major and minor axes
    major_axis_x = np.array([center_shift + x_radius, center_shift - x_radius])
    major_axis_y = np.array([0, 0])
    minor_axis_x = np.array([center_shift, center_shift])
    minor_axis_y = np.array([y_radius, -y_radius])
    major_axis_x_rot, major_axis_y_rot = rotate_points(major_axis_x, major_axis_y, np.deg2rad(rotation_deg))
    minor_axis_x_rot, minor_axis_y_rot = rotate_points(minor_axis_x, minor_axis_y, np.deg2rad(rotation_deg))
    ax.plot(np.arctan2(major_axis_y_rot, major_axis_x_rot), np.sqrt(major_axis_x_rot**2 + major_axis_y_rot**2), 'red', linestyle='--', linewidth=1)
    ax.plot(np.arctan2(minor_axis_y_rot, minor_axis_x_rot), np.sqrt(minor_axis_x_rot**2 + minor_axis_y_rot**2), 'red', linestyle='--', linewidth=1)

    inside_fov = []

    # Plot satellite traces
    for satellite_name, positions in positions_over_time.items():
        r = [pos[0] for pos in positions]
        angle = [pos[1] for pos in positions]
        inside = False
        for r_i, angle_i in zip(r, angle):
            x_point = r_i * np.cos(angle_i)
            y_point = r_i * np.sin(angle_i)
            x_point_rot, y_point_rot = rotate_points(x_point, y_point, -np.deg2rad(rotation_deg))
            x_point_rot -= center_shift
            if (x_point_rot**2 / x_radius**2) + (y_point_rot**2 / y_radius**2) <= 1:
                inside = True
                break
        if inside:
            ax.plot(angle, r, color="g", label="Inside FOV")
            inside_fov.append(satellite_name)
        else:
            ax.plot(angle, r, color="b", label="Outside FOV")
        ax.annotate(satellite_name, xy=(angle[0], r[0]), xytext=(0, 5), textcoords='offset points', ha='center', va='bottom', fontsize=6, bbox=dict(boxstyle='round,pad=0.5', edgecolor='none', facecolor='none', alpha=0.6))

    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), loc='upper right')
    
    # Format the observation time
    observation_time_str = observation_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')
    latitude_str = f"{abs(observer_location.latitude.degrees)}° {'N' if observer_location.latitude.degrees >= 0 else 'S'}"
    longitude_str = f"{abs(observer_location.longitude.degrees)}° {'E' if observer_location.longitude.degrees >= 0 else 'W'}"
    observer_location_str = f"{latitude_str}, {longitude_str}"
    ax.set_title(f'{tilt_deg}° Tilt, {rotation_deg}° Rotation\nObservation Time: {observation_time_str}\nObserver Location: {observer_location_str}', va='bottom')

    plt.show()
    print("Satellites inside the FOV:", inside_fov)

if __name__ == "__main__":
    satellites = load_data()
    initial_time = set_observation_time(2024, 5, 26, 22, 5, 15)
    observer_location = wgs84.latlon(latitude_degrees=48.461195499999974, longitude_degrees=-123.31172833333332, elevation_m=73)
    interval_seconds = 15
    positions_over_time = calculate_satellite_positions_over_time(satellites, observer_location, initial_time, interval_seconds)
    draw_fov(27, -1.3, positions_over_time, initial_time, observer_location)
# Out:
# Loaded 6010 satellites
# Satellites inside the FOV: ['STARLINK-1090', 'STARLINK-1107', 'STARLINK-1166', 'STARLINK-1245', 'STARLINK-1631', 'STARLINK-1595', 'STARLINK-1713', 'STARLINK-1670', 'STARLINK-1944', 'STARLINK-1838', 'STARLINK-2303', 'STARLINK-2621', 'STARLINK-2602', 'STARLINK-3003', 'STARLINK-3369', 'STARLINK-3361', 'STARLINK-3529', 'STARLINK-3507', 'STARLINK-3617', 'STARLINK-3577', 'STARLINK-4401', 'STARLINK-4340', 'STARLINK-4753', 'STARLINK-4796', 'STARLINK-5175', 'STARLINK-5203', 'STARLINK-5247', 'STARLINK-5264', 'STARLINK-6054', 'STARLINK-5527', 'STARLINK-30320', 'STARLINK-30814', 'STARLINK-31232', 'STARLINK-31263', 'STARLINK-31175', 'STARLINK-31269']

# %%
from skyfield.api import load, wgs84, Topos
import matplotlib.pyplot as plt
import numpy as np
from datetime import timedelta
import math

def load_data():
    stations_url = 'https://celestrak.org/NORAD/elements/gp.php?GROUP=starlink&FORMAT=tle'
    satellites = load.tle_file(stations_url)
    print('Loaded', len(satellites), 'satellites')
    return satellites

def set_observation_time(year, month, day, hour, minute, second):
    ts = load.timescale()
    return ts.utc(year, month, day, hour, minute, second)

def calculate_satellite_positions(satellites, observer_location, observation_time):
    locations = []
    sats = []
    min_elevation = 20
    closest_sat = None
    closest_distance = float('inf')
    closest_azimuth = None
    closest_elevation = None
    for satellite in satellites:
        difference = satellite - observer_location
        topocentric = difference.at(observation_time)
        alt, az, distance = topocentric.altaz()
        if alt.degrees > min_elevation:
            loc = [(90 - alt.degrees, np.radians(az.degrees))]
            locations.append(loc)
            sats.append(satellite)
            if distance.km < closest_distance:
                closest_distance = distance.km
                closest_sat = satellite
                closest_azimuth = az.degrees
                closest_elevation = alt.degrees
            print(f"{satellite} at Azimuth: {az.degrees}°, Altitude: {alt.degrees}°, Distance: {distance.km} km")
    return locations, sats, closest_sat, closest_azimuth, closest_elevation

def rotate_points(x, y, angle):
    x_rot = x * np.cos(angle) - y * np.sin(angle)
    y_rot = x * np.sin(angle) + y * np.cos(angle)
    return x_rot, y_rot

def draw_fov(tilt_deg, rotation_deg, locations, sats, observation_time, observer_location, closest_azimuth, closest_elevation):
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'}, figsize=(16, 16))

    # Plot settings
    ax.set_ylim(0, 90)
    ax.set_yticks(np.arange(0, 91, 10))
    ax.set_theta_zero_location("N")
    ax.set_theta_direction(-1)
    ax.grid(True)

    zenith_legend = plt.Line2D([0], [0], color='gray', linestyle='-', linewidth=1, label='Zenith Lines')
    azimuth_legend = plt.Line2D([0], [0], color='black', linestyle='-', linewidth=1, label='Azimuth')
    FOV = plt.Line2D([0], [0], color='red', linestyle='-', linewidth=2, label='FOV')
    Axis = plt.Line2D([0], [0], color='red', linestyle='--', linewidth=1, label='FOV axis')
    ax.add_artist(zenith_legend)
    ax.add_artist(azimuth_legend)
    ax.add_artist(FOV)
    ax.add_artist(Axis)

    # FOV ellipse
    base_radius = 60
    center_shift = tilt_deg
    x_radius = base_radius
    y_radius = math.sqrt(base_radius**2 - tilt_deg**2)

    theta = np.linspace(0, 2 * np.pi, 300)
    x = x_radius * np.cos(theta) + center_shift
    y = y_radius * np.sin(theta)
    r = np.sqrt(x**2 + y**2)
    angles = np.arctan2(y, x) + np.deg2rad(rotation_deg)
    ax.plot(angles, r, 'r')

    # Plot major and minor axes
    major_axis_x = np.array([center_shift + x_radius, center_shift - x_radius])
    major_axis_y = np.array([0, 0])
    minor_axis_x = np.array([center_shift, center_shift])
    minor_axis_y = np.array([y_radius, -y_radius])
    major_axis_x_rot, major_axis_y_rot = rotate_points(major_axis_x, major_axis_y, np.deg2rad(rotation_deg))
    minor_axis_x_rot, minor_axis_y_rot = rotate_points(minor_axis_x, minor_axis_y, np.deg2rad(rotation_deg))
    ax.plot(np.arctan2(major_axis_y_rot, major_axis_x_rot), np.sqrt(major_axis_x_rot**2 + major_axis_y_rot**2), 'red', linestyle='--', linewidth=1)
    ax.plot(np.arctan2(minor_axis_y_rot, minor_axis_x_rot), np.sqrt(minor_axis_x_rot**2 + minor_axis_y_rot**2), 'red', linestyle='--', linewidth=1)

    inside_fov = []

    # Plot satellites
    for loc, sat in zip(locations, sats):
        loc = np.array(loc)
        r = loc[:, 0]
        angle = loc[:, 1]
        inside = False
        for r_i, angle_i in zip(r, angle):
            x_point = r_i * np.cos(angle_i)
            y_point = r_i * np.sin(angle_i)
            x_point_rot, y_point_rot = rotate_points(x_point, y_point, -np.deg2rad(rotation_deg))
            x_point_rot -= center_shift
            if (x_point_rot**2 / x_radius**2) + (y_point_rot**2 / y_radius**2) <= 1:
                inside = True
                break
        if inside:
            ax.scatter(angle, r, color="g", label="Inside FOV")
            inside_fov.append(sat.name)
        else:
            ax.scatter(angle, r, color="b", label="Outside FOV")
        ax.annotate(sat.name, xy=(angle, r), xytext=(0, 5), textcoords='offset points', ha='center', va='bottom', fontsize=6, bbox=dict(boxstyle='round,pad=0.5', edgecolor='none', facecolor='none', alpha=0.6))

    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), loc='upper right')
    
    # Format the observation time
    observation_time_str = observation_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')
    latitude_str = f"{abs(observer_location.latitude.degrees)}° {'N' if observer_location.latitude.degrees >= 0 else 'S'}"
    longitude_str = f"{abs(observer_location.longitude.degrees)}° {'E' if observer_location.longitude.degrees >= 0 else 'W'}"
    observer_location_str = f"{latitude_str}, {longitude_str}"
    ax.set_title(f'{tilt_deg}° Tilt, {rotation_deg}° Rotation\nObservation Time: {observation_time_str}\nObserver Location: {observer_location_str}', va='bottom')
    
    ax.scatter(np.deg2rad(closest_azimuth), 90-closest_elevation, color='red', marker='o', s=150)
    plt.show()
    print("Satellites inside the FOV:", inside_fov)

def find_next_pass(satellite, observer_location, start_time, tilt_deg, rotation_deg):
    ts = load.timescale()
    time = start_time
    in_fov = False
    first_entry_time = None
    while True:
        time += timedelta(seconds=10)  # Increase the time in 10-second steps
        difference = satellite - observer_location
        topocentric = difference.at(time)
        alt, az, distance = topocentric.altaz()
        if alt.degrees > 20:  # Check if the satellite is above the minimum elevation
            x_point = (90 - alt.degrees) * np.cos(np.radians(az.degrees))
            y_point = (90 - alt.degrees) * np.sin(np.radians(az.degrees))
            x_point_rot, y_point_rot = rotate_points(x_point, y_point, -np.deg2rad(rotation_deg))
            x_point_rot -= tilt_deg
            x_radius = 60
            y_radius = math.sqrt(60**2 - tilt_deg**2)
            inside_fov = (x_point_rot**2 / x_radius**2) + (y_point_rot**2 / y_radius**2) <= 1

            if inside_fov and not in_fov:
                in_fov = True
                if first_entry_time is None:
                    first_entry_time = time
                else:
                    return first_entry_time, time
            elif not inside_fov and in_fov:
                in_fov = False

if __name__ == "__main__":
    satellites = load_data()
    initial_time = set_observation_time(2024, 5, 25, 20, 36, 35)
    observer_location = wgs84.latlon(latitude_degrees=48.461195499999974, longitude_degrees=-123.31172833333332, elevation_m=73)
    locations, sats, closest_sat, closest_azimuth, closest_elevation = calculate_satellite_positions(satellites, observer_location, initial_time)
    draw_fov(27, -1.3, locations, sats, initial_time, observer_location, closest_azimuth, closest_elevation)
    
    first_entry_time, next_pass_time = find_next_pass(closest_sat, observer_location, initial_time, 27, -1.3)
    print(f"First entry time: {first_entry_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')}")
    print(f"Next pass time: {next_pass_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')}")
# Out:
# Loaded 6010 satellites
# STARLINK-1079 catalog #44937 epoch 2024-05-24 01:35:29 UTC at Azimuth: 239.85675904012564°, Altitude: 34.39209972972931°, Distance: 861.4098727868143 km
# STARLINK-1089 catalog #44967 epoch 2024-05-24 10:49:03 UTC at Azimuth: 12.312697465814878°, Altitude: 50.2184289236856°, Distance: 700.1736172718533 km
# STARLINK-1107 catalog #44972 epoch 2024-05-23 20:28:25 UTC at Azimuth: 56.05011067140277°, Altitude: 21.317652143475875°, Distance: 1247.7147246682391 km
# STARLINK-1179 catalog #45085 epoch 2024-05-23 10:47:59 UTC at Azimuth: 275.87841308503005°, Altitude: 29.941086796475453°, Distance: 996.5275695853353 km
# STARLINK-1481 catalog #45742 epoch 2024-05-24 10:37:08 UTC at Azimuth: 197.75148706088163°, Altitude: 27.66737530281221°, Distance: 1050.5624273789338 km
# STARLINK-1596 catalog #46141 epoch 2024-05-23 20:22:35 UTC at Azimuth: 69.43919218200318°, Altitude: 27.086586895993882°, Distance: 1068.4778229770673 km
# STARLINK-1640 catalog #46173 epoch 2024-05-23 20:33:12 UTC at Azimuth: 259.2076403047492°, Altitude: 31.3765954418457°, Distance: 963.9566051582725 km
# STARLINK-1716 catalog #46672 epoch 2024-05-23 20:19:13 UTC at Azimuth: 232.05563139979103°, Altitude: 39.00911365466944°, Distance: 827.5435122304616 km
# STARLINK-1921 catalog #46752 epoch 2024-05-24 01:16:29 UTC at Azimuth: 64.77576274918187°, Altitude: 23.787123880819916°, Distance: 1165.4935245576025 km
# STARLINK-1832 catalog #46780 epoch 2024-05-24 01:17:49 UTC at Azimuth: 293.28404885027214°, Altitude: 50.48817419665281°, Distance: 697.4435494041966 km
# STARLINK-1862 catalog #47149 epoch 2024-05-23 23:38:19 UTC at Azimuth: 46.24403751516794°, Altitude: 29.821239768189812°, Distance: 1001.5084496234741 km
# STARLINK-2322 catalog #47791 epoch 2024-05-23 20:17:55 UTC at Azimuth: 128.91047976523507°, Altitude: 23.42956903919648°, Distance: 1172.6388508949235 km
# STARLINK-2364 catalog #47904 epoch 2024-05-24 12:17:18 UTC at Azimuth: 8.099917472047142°, Altitude: 73.50561948598673°, Distance: 573.7820975657143 km
# STARLINK-2398 catalog #47918 epoch 2024-05-23 18:50:22 UTC at Azimuth: 304.6789106505357°, Altitude: 22.28684879694345°, Distance: 1215.006595471454 km
# STARLINK-2282 catalog #48018 epoch 2024-05-24 01:21:18 UTC at Azimuth: 243.72565901274433°, Altitude: 28.58615438828111°, Distance: 1025.711941164919 km
# STARLINK-2294 catalog #48020 epoch 2024-05-24 12:19:22 UTC at Azimuth: 315.31752686661946°, Altitude: 38.88669537374517°, Distance: 831.8812615564716 km
# STARLINK-2278 catalog #48026 epoch 2024-05-24 02:57:59 UTC at Azimuth: 189.45717879017118°, Altitude: 29.052099149714774°, Distance: 1015.1807637065176 km
# STARLINK-2299 catalog #48029 epoch 2024-05-24 02:56:00 UTC at Azimuth: 147.5871834118532°, Altitude: 53.799060898225136°, Distance: 668.3872282923862 km
# STARLINK-2572 catalog #48372 epoch 2024-05-23 22:28:11 UTC at Azimuth: 13.262080478719206°, Altitude: 78.22405929294403°, Distance: 372.29871569164425 km
# STARLINK-2505 catalog #48411 epoch 2024-05-23 23:39:37 UTC at Azimuth: 308.5565180767247°, Altitude: 29.739446822249814°, Distance: 1003.4527509982526 km
# STARLINK-3309 catalog #50158 epoch 2024-05-23 20:23:38 UTC at Azimuth: 108.46384191734718°, Altitude: 22.145925774267°, Distance: 1202.9200944719705 km
# STARLINK-3288 catalog #50160 epoch 2024-05-23 15:41:23 UTC at Azimuth: 301.83959695523413°, Altitude: 36.46861858864952°, Distance: 859.1686065132038 km
# STARLINK-3282 catalog #50177 epoch 2024-05-23 18:48:12 UTC at Azimuth: 153.3886539338638°, Altitude: 46.481273163413306°, Distance: 725.0449304348384 km
# STARLINK-3259 catalog #50192 epoch 2024-05-24 10:43:22 UTC at Azimuth: 267.6721136763118°, Altitude: 22.398782650201753°, Distance: 1194.774099698481 km
# STARLINK-3269 catalog #50194 epoch 2024-05-23 20:20:58 UTC at Azimuth: 165.05425338278945°, Altitude: 20.323338532728386°, Distance: 1265.326264208766 km
# STARLINK-3390 catalog #51119 epoch 2024-05-24 06:00:01 UTC at Azimuth: 325.25105931232235°, Altitude: 41.5819898326065°, Distance: 526.113988197709 km
# STARLINK-3185 catalog #51144 epoch 2024-05-23 20:34:14 UTC at Azimuth: 305.52446217748536°, Altitude: 32.94350785901189°, Distance: 922.5005668985407 km
# STARLINK-3181 catalog #51461 epoch 2024-05-23 20:30:12 UTC at Azimuth: 335.7757831642814°, Altitude: 39.18798215753672°, Distance: 817.0260042852182 km
# STARLINK-3532 catalog #51727 epoch 2024-05-23 20:39:28 UTC at Azimuth: 217.82447150117486°, Altitude: 33.93309756879189°, Distance: 901.1493109092121 km
# STARLINK-3520 catalog #51741 epoch 2024-05-24 01:23:02 UTC at Azimuth: 270.05559569071437°, Altitude: 65.86466537088303°, Distance: 591.8544426290772 km
# STARLINK-3501 catalog #51748 epoch 2024-05-23 20:36:49 UTC at Azimuth: 274.8687563726407°, Altitude: 24.447311835466678°, Distance: 1129.9357276836631 km
# STARLINK-3507 catalog #51753 epoch 2024-05-23 22:08:17 UTC at Azimuth: 50.03919351264067°, Altitude: 28.38555050375055°, Distance: 1023.4127830379568 km
# STARLINK-3617 catalog #51780 epoch 2024-05-24 02:59:41 UTC at Azimuth: 103.92322707917353°, Altitude: 27.805477707781893°, Distance: 1035.6956564539082 km
# STARLINK-3941 catalog #52638 epoch 2024-05-23 15:40:03 UTC at Azimuth: 78.12404281673868°, Altitude: 32.22705140254553°, Distance: 935.4243250223419 km
# STARLINK-4674 catalog #53591 epoch 2024-05-23 20:21:37 UTC at Azimuth: 149.5481792160147°, Altitude: 22.14253053535801°, Distance: 1200.5009216841545 km
# STARLINK-4647 catalog #53608 epoch 2024-05-24 09:06:02 UTC at Azimuth: 235.97951296351266°, Altitude: 25.28226250470654°, Distance: 1103.501552111415 km
# STARLINK-4651 catalog #53729 epoch 2024-05-24 10:44:03 UTC at Azimuth: 268.1262617124536°, Altitude: 75.40587345632487°, Distance: 560.5493350425572 km
# STARLINK-4712 catalog #53798 epoch 2024-05-23 18:52:45 UTC at Azimuth: 33.14465530959511°, Altitude: 46.98536765125838°, Distance: 721.8289695485146 km
# STARLINK-4759 catalog #53829 epoch 2024-05-23 23:45:36 UTC at Azimuth: 304.9748772866182°, Altitude: 39.088734945675185°, Distance: 817.9801060925075 km
# STARLINK-4753 catalog #53845 epoch 2024-05-23 20:30:52 UTC at Azimuth: 40.408795643314015°, Altitude: 31.682956440062114°, Distance: 948.4061582975675 km
# STARLINK-4788 catalog #53863 epoch 2024-05-23 18:56:48 UTC at Azimuth: 308.5485201941929°, Altitude: 24.965411887773406°, Distance: 1115.9826122748518 km
# STARLINK-5052 catalog #53893 epoch 2024-05-24 01:23:34 UTC at Azimuth: 220.05626692459393°, Altitude: 74.35886099163221°, Distance: 562.9993425028296 km
# STARLINK-4796 catalog #53909 epoch 2024-05-23 20:33:33 UTC at Azimuth: 55.625792680981256°, Altitude: 26.613522036623785°, Distance: 1069.0670097155287 km
# STARLINK-5195 catalog #54051 epoch 2024-05-24 03:01:43 UTC at Azimuth: 140.47468721568646°, Altitude: 25.368161251566754°, Distance: 1099.606899710461 km
# STARLINK-5203 catalog #54104 epoch 2024-05-23 23:43:32 UTC at Azimuth: 359.8470310125781°, Altitude: 43.85325087748389°, Distance: 755.9670491902566 km
# STARLINK-5264 catalog #54206 epoch 2024-05-23 20:35:28 UTC at Azimuth: 52.067188756364715°, Altitude: 52.229985954637165°, Distance: 673.3409157711843 km
# STARLINK-5632 catalog #55400 epoch 2024-05-24 11:58:39 UTC at Azimuth: 179.9026955204196°, Altitude: 48.46653750819857°, Distance: 749.8723748826834 km
# STARLINK-5736 catalog #55584 epoch 2024-05-24 12:13:23 UTC at Azimuth: 200.80237869459555°, Altitude: 25.970943791052402°, Distance: 1117.3514461562086 km
# STARLINK-5487 catalog #55652 epoch 2024-05-24 02:41:51 UTC at Azimuth: 302.27105314552364°, Altitude: 27.148883153020975°, Distance: 1118.226964530697 km
# STARLINK-5811 catalog #55787 epoch 2024-05-24 04:18:20 UTC at Azimuth: 57.829587451144796°, Altitude: 38.56626252387814°, Distance: 878.079075921008 km
# STARLINK-5957 catalog #55995 epoch 2024-05-23 23:37:11 UTC at Azimuth: 182.51252440381515°, Altitude: 27.370773958093984°, Distance: 1078.5377910760128 km
# STARLINK-5771 catalog #56023 epoch 2024-05-23 23:32:45 UTC at Azimuth: 128.59197048993622°, Altitude: 27.24100597569937°, Distance: 1083.8675260745867 km
# STARLINK-6233 catalog #57229 epoch 2024-05-23 20:21:42 UTC at Azimuth: 222.34502031249122°, Altitude: 31.091849033261408°, Distance: 990.0070977289009 km
# STARLINK-5503 catalog #57257 epoch 2024-05-23 21:53:01 UTC at Azimuth: 160.84263686114187°, Altitude: 30.717458973488657°, Distance: 997.8651104707193 km
# STARLINK-30576 catalog #58065 epoch 2024-05-24 01:07:19 UTC at Azimuth: 167.74365035494048°, Altitude: 38.867175048925596°, Distance: 848.168706087262 km
# STARLINK-30802 catalog #58150 epoch 2024-05-23 22:45:13 UTC at Azimuth: 62.50307223629609°, Altitude: 27.741985892437036°, Distance: 938.0443890892413 km
# STARLINK-30833 catalog #58152 epoch 2024-05-23 22:45:41 UTC at Azimuth: 61.411814873045266°, Altitude: 37.47333798326463°, Distance: 757.7581588584338 km
# STARLINK-30964 catalog #58402 epoch 2024-05-23 23:35:27 UTC at Azimuth: 138.82496321591913°, Altitude: 26.492805472914203°, Distance: 1105.9685000694458 km
# STARLINK-30944 catalog #58451 epoch 2024-05-24 01:11:36 UTC at Azimuth: 220.8547905362216°, Altitude: 25.278561058624753°, Distance: 1138.384761273378 km
# STARLINK-31102 catalog #58715 epoch 2024-05-23 15:31:46 UTC at Azimuth: 70.95930170196071°, Altitude: 56.82196865761718°, Distance: 653.8866150630288 km
# STARLINK-31216 catalog #58857 epoch 2024-05-23 21:05:47 UTC at Azimuth: 228.15728587384754°, Altitude: 25.466120148605693°, Distance: 1002.8572377364936 km
# STARLINK-31434 catalog #59215 epoch 2024-05-23 18:20:00 UTC at Azimuth: 309.6156079452462°, Altitude: 26.048210558824877°, Distance: 918.0270121102778 km
# STARLINK-31639 catalog #59261 epoch 2024-05-23 19:54:26 UTC at Azimuth: 38.04257395411708°, Altitude: 29.497025837066854°, Distance: 840.7986298311981 km
# STARLINK-31474 catalog #59304 epoch 2024-05-24 02:14:17 UTC at Azimuth: 134.13959219162012°, Altitude: 23.12627553041061°, Distance: 986.4517101882777 km
# STARLINK-31493 catalog #59329 epoch 2024-05-24 13:02:12 UTC at Azimuth: 188.68014691927624°, Altitude: 24.834858118377436°, Distance: 939.458423979216 km
# Satellites inside the FOV: ['STARLINK-1089', 'STARLINK-1832', 'STARLINK-1862', 'STARLINK-2364', 'STARLINK-2294', 'STARLINK-2572', 'STARLINK-2505', 'STARLINK-3288', 'STARLINK-3390', 'STARLINK-3185', 'STARLINK-3181', 'STARLINK-3520', 'STARLINK-3507', 'STARLINK-4651', 'STARLINK-4712', 'STARLINK-4759', 'STARLINK-4753', 'STARLINK-4788', 'STARLINK-5052', 'STARLINK-4796', 'STARLINK-5203', 'STARLINK-5264', 'STARLINK-5487', 'STARLINK-5811', 'STARLINK-30833', 'STARLINK-31102', 'STARLINK-31434', 'STARLINK-31639']
# First entry time: 2024-05-25 20:36:45 (UTC)
# Next pass time: 2024-05-25 22:10:55 (UTC)

# %%
from skyfield.api import load, wgs84, Topos
import matplotlib.pyplot as plt
import numpy as np
from datetime import timedelta
import math

def load_data():
    stations_url = 'https://celestrak.org/NORAD/elements/gp.php?GROUP=starlink&FORMAT=tle'
    satellites = load.tle_file(stations_url)
    print('Loaded', len(satellites), 'satellites')
    return satellites

def set_observation_time(year, month, day, hour, minute, second):
    ts = load.timescale()
    return ts.utc(year, month, day, hour, minute, second)

def calculate_satellite_positions(satellites, observer_location, observation_time):
    locations = []
    sats = []
    min_elevation = 20
    for satellite in satellites:
        difference = satellite - observer_location
        topocentric = difference.at(observation_time)
        alt, az, distance = topocentric.altaz()
        if alt.degrees > min_elevation:
            loc = [(90 - alt.degrees, np.radians(az.degrees))]
            locations.append(loc)
            sats.append(satellite)
            print(f"{satellite.name} at Azimuth: {az.degrees}°, Altitude: {alt.degrees}°, Distance: {distance.km} km")
    return locations, sats

def rotate_points(x, y, angle):
    x_rot = x * np.cos(angle) - y * np.sin(angle)
    y_rot = x * np.sin(angle) + y * np.cos(angle)
    return x_rot, y_rot

def draw_fov(tilt_deg, rotation_deg, locations, sats, observation_time, observer_location):
    fig, ax = plt.subplots(subplot_kw={'projection': 'polar'}, figsize=(16, 16))

    # Plot settings
    ax.set_ylim(0, 90)
    ax.set_yticks(np.arange(0, 91, 10))
    ax.set_theta_zero_location("N")
    ax.set_theta_direction(-1)
    ax.grid(True)

    zenith_legend = plt.Line2D([0], [0], color='gray', linestyle='-', linewidth=1, label='Zenith Lines')
    azimuth_legend = plt.Line2D([0], [0], color='black', linestyle='-', linewidth=1, label='Azimuth')
    FOV = plt.Line2D([0], [0], color='red', linestyle='-', linewidth=2, label='FOV')
    Axis = plt.Line2D([0], [0], color='red', linestyle='--', linewidth=1, label='FOV axis')
    ax.add_artist(zenith_legend)
    ax.add_artist(azimuth_legend)
    ax.add_artist(FOV)
    ax.add_artist(Axis)

    # FOV ellipse
    base_radius = 60
    center_shift = tilt_deg
    x_radius = base_radius
    y_radius = math.sqrt(base_radius**2 - tilt_deg**2)

    theta = np.linspace(0, 2 * np.pi, 300)
    x = x_radius * np.cos(theta) + center_shift
    y = y_radius * np.sin(theta)
    r = np.sqrt(x**2 + y**2)
    angles = np.arctan2(y, x) + np.deg2rad(rotation_deg)
    ax.plot(angles, r, 'r')

    # Plot major and minor axes
    major_axis_x = np.array([center_shift + x_radius, center_shift - x_radius])
    major_axis_y = np.array([0, 0])
    minor_axis_x = np.array([center_shift, center_shift])
    minor_axis_y = np.array([y_radius, -y_radius])
    major_axis_x_rot, major_axis_y_rot = rotate_points(major_axis_x, major_axis_y, np.deg2rad(rotation_deg))
    minor_axis_x_rot, minor_axis_y_rot = rotate_points(minor_axis_x, minor_axis_y, np.deg2rad(rotation_deg))
    ax.plot(np.arctan2(major_axis_y_rot, major_axis_x_rot), np.sqrt(major_axis_x_rot**2 + major_axis_y_rot**2), 'red', linestyle='--', linewidth=1)
    ax.plot(np.arctan2(minor_axis_y_rot, minor_axis_x_rot), np.sqrt(minor_axis_x_rot**2 + minor_axis_y_rot**2), 'red', linestyle='--', linewidth=1)

    inside_fov = []

    # Plot satellites
    for loc, sat in zip(locations, sats):
        loc = np.array(loc)
        r = loc[:, 0]
        angle = loc[:, 1]
        inside = False
        for r_i, angle_i in zip(r, angle):
            x_point = r_i * np.cos(angle_i)
            y_point = r_i * np.sin(angle_i)
            x_point_rot, y_point_rot = rotate_points(x_point, y_point, -np.deg2rad(rotation_deg))
            x_point_rot -= center_shift
            if (x_point_rot**2 / x_radius**2) + (y_point_rot**2 / y_radius**2) <= 1:
                inside = True
                break
        if inside:
            ax.scatter(angle, r, color="g", label="Inside FOV")
            inside_fov.append(sat.name)
        else:
            ax.scatter(angle, r, color="b", label="Outside FOV")
        ax.annotate(sat.name, xy=(angle, r), xytext=(0, 5), textcoords='offset points', ha='center', va='bottom', fontsize=6, bbox=dict(boxstyle='round,pad=0.5', edgecolor='none', facecolor='none', alpha=0.6))

    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    ax.legend(by_label.values(), by_label.keys(), loc='upper right')
    
    # Format the observation time
    observation_time_str = observation_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')
    latitude_str = f"{abs(observer_location.latitude.degrees)}° {'N' if observer_location.latitude.degrees >= 0 else 'S'}"
    longitude_str = f"{abs(observer_location.longitude.degrees)}° {'E' if observer_location.longitude.degrees >= 0 else 'W'}"
    observer_location_str = f"{latitude_str}, {longitude_str}"
    ax.set_title(f'{tilt_deg}° Tilt, {rotation_deg}° Rotation\nObservation Time: {observation_time_str}\nObserver Location: {observer_location_str}', va='bottom')
    
    plt.show()
    print("Satellites inside the FOV:", inside_fov)

def is_inside_fov(alt_degrees, az_degrees, tilt_deg, rotation_deg):
    x_radius = 60
    y_radius = math.sqrt(60**2 - tilt_deg**2)
    x_point = (90 - alt_degrees) * np.cos(np.radians(az_degrees))
    y_point = (90 - alt_degrees) * np.sin(np.radians(az_degrees))
    x_point_rot, y_point_rot = rotate_points(x_point, y_point, -np.deg2rad(rotation_deg))
    x_point_rot -= tilt_deg
    return (x_point_rot**2 / x_radius**2) + (y_point_rot**2 / y_radius**2) <= 1

def find_next_pass(satellite, observer_location, start_time, tilt_deg, rotation_deg):
    ts = load.timescale()
    time = start_time
    difference = satellite - observer_location
    topocentric = difference.at(time)
    alt, az, _ = topocentric.altaz()
    was_inside = is_inside_fov(alt.degrees, az.degrees, tilt_deg, rotation_deg)
    entry_time = None

    while True:
        time += timedelta(seconds=10)  # Increase the time in 10-second steps
        topocentric = difference.at(time)
        alt, az, _ = topocentric.altaz()
        inside_fov = is_inside_fov(alt.degrees, az.degrees, tilt_deg, rotation_deg)

        if not was_inside and inside_fov:
            entry_time = time
        if was_inside and not inside_fov:
            was_inside = False
            if entry_time is not None:
                break
        was_inside = inside_fov

    return start_time, entry_time

if __name__ == "__main__":
    satellites = load_data()
    initial_time = set_observation_time(2024, 5, 24, 20, 36, 35)
    observer_location = wgs84.latlon(latitude_degrees=48.461195499999974, longitude_degrees=-123.31172833333332, elevation_m=73)
    locations, sats = calculate_satellite_positions(satellites, observer_location, initial_time)
    
    # Pick the first satellite from the list for this example
    selected_sat = sats[0]
    print(f"Tracking satellite: {selected_sat.name}")

    draw_fov(27, -1.3, locations, sats, initial_time, observer_location)
    
    first_entry_time, next_pass_time = find_next_pass(selected_sat, observer_location, initial_time, 27, -1.3)
    print(f"First entry time: {first_entry_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')}")
    print(f"Next pass time: {next_pass_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')}")
    print(f"Satellite name: {selected_sat.name}")
    print(f"Satellite info: Azimuth: {az.degrees}°, Altitude: {alt.degrees}°")
# Out:
# Loaded 6010 satellites
# STARLINK-1096 at Azimuth: 57.33552213208402°, Altitude: 50.368685225831854°, Distance: 603.2118142185975 km
# STARLINK-1100 at Azimuth: 343.0083992954603°, Altitude: 36.333909889414194°, Distance: 581.6707924254206 km
# STARLINK-1090 at Azimuth: 323.1927008408771°, Altitude: 61.547040893810504°, Distance: 620.6706902936343 km
# STARLINK-1166 at Azimuth: 317.36790815109265°, Altitude: 34.648954049163°, Distance: 902.0661992469013 km
# STARLINK-1150 at Azimuth: 308.58577166899835°, Altitude: 26.655686511915896°, Distance: 1081.4318754631825 km
# STARLINK-1506 at Azimuth: 218.90572818981542°, Altitude: 41.2790575217792°, Distance: 794.8464737462938 km
# STARLINK-1639 at Azimuth: 49.28039746208782°, Altitude: 34.21710475765879°, Distance: 910.1475980167614 km
# STARLINK-1586 at Azimuth: 52.49004330844698°, Altitude: 24.506029407437467°, Distance: 1143.5236033244757 km
# STARLINK-1595 at Azimuth: 243.22004849295016°, Altitude: 21.097905296074476°, Distance: 1253.50081578837 km
# STARLINK-1713 at Azimuth: 178.74648802998453°, Altitude: 32.658046913196266°, Distance: 936.1226067120443 km
# STARLINK-1775 at Azimuth: 67.47524822072666°, Altitude: 65.55752610889846°, Distance: 601.3075342985544 km
# STARLINK-1789 at Azimuth: 184.10579083591966°, Altitude: 24.78718725327668°, Distance: 1129.0564313160587 km
# STARLINK-1792 at Azimuth: 270.36199487082064°, Altitude: 36.495176981702095°, Distance: 868.3434634030344 km
# STARLINK-1905 at Azimuth: 77.1823389030525°, Altitude: 35.61979723504115°, Distance: 884.230978084104 km
# STARLINK-1944 at Azimuth: 260.53389243680186°, Altitude: 38.72981463098482°, Distance: 832.8155884764233 km
# STARLINK-1838 at Azimuth: 292.1679148374751°, Altitude: 22.606825326777294°, Distance: 1204.3399990494675 km
# STARLINK-2395 at Azimuth: 113.88639496998405°, Altitude: 36.066767445980545°, Distance: 874.948057189307 km
# STARLINK-2361 at Azimuth: 327.59501457428104°, Altitude: 48.46217271427056°, Distance: 716.5275918242966 km
# STARLINK-2365 at Azimuth: 58.06046870771892°, Altitude: 53.382170425816874°, Distance: 673.4034265293565 km
# STARLINK-2374 at Azimuth: 2.9514677894368506°, Altitude: 42.761466118800456°, Distance: 779.1224209766316 km
# STARLINK-2397 at Azimuth: 74.18736708262499°, Altitude: 21.961544071390662°, Distance: 1225.660287114694 km
# STARLINK-2307 at Azimuth: 290.63800356039746°, Altitude: 21.173117616490142°, Distance: 1253.571496226816 km
# STARLINK-3297 at Azimuth: 334.07377429206565°, Altitude: 55.25575331576998°, Distance: 651.0182985507756 km
# STARLINK-3287 at Azimuth: 293.7498768949972°, Altitude: 26.088459641983082°, Distance: 1083.003397039439 km
# STARLINK-3267 at Azimuth: 197.16124420904487°, Altitude: 47.3727997374148°, Distance: 715.5573628295596 km
# STARLINK-3344 at Azimuth: 330.2084370219006°, Altitude: 39.054509043196774°, Distance: 819.154690621994 km
# STARLINK-3183 at Azimuth: 298.00822917608946°, Altitude: 23.536830278793918°, Distance: 1159.5949649047539 km
# STARLINK-3364 at Azimuth: 3.096943268037839°, Altitude: 63.882472231560385°, Distance: 600.919475643102 km
# STARLINK-3182 at Azimuth: 55.26124815439717°, Altitude: 27.386658416910027°, Distance: 1048.426394580548 km
# STARLINK-3515 at Azimuth: 237.01679904805448°, Altitude: 25.27107208830595°, Distance: 1103.2015929035786 km
# STARLINK-3505 at Azimuth: 272.72514162040216°, Altitude: 41.030004836103636°, Distance: 790.0169887796568 km
# STARLINK-3610 at Azimuth: 115.29801870580704°, Altitude: 41.49520299235179°, Distance: 783.7409525675592 km
# STARLINK-4001 at Azimuth: 20.20088163605413°, Altitude: 39.261097311771366°, Distance: 816.4137241015125 km
# STARLINK-3994 at Azimuth: 316.68093284064906°, Altitude: 31.128750258743874°, Distance: 960.3948292662218 km
# STARLINK-3868 at Azimuth: 73.91565587723186°, Altitude: 50.28376705861334°, Distance: 689.8397686261357 km
# STARLINK-4672 at Azimuth: 287.5915418661841°, Altitude: 23.316587440073366°, Distance: 1165.8873276805145 km
# STARLINK-4590 at Azimuth: 171.56898187188145°, Altitude: 25.364735374306775°, Distance: 1099.346859430736 km
# STARLINK-4610 at Azimuth: 209.815485757867°, Altitude: 35.97635404630787°, Distance: 863.5189718811678 km
# STARLINK-4716 at Azimuth: 270.5334254280376°, Altitude: 47.02347117903628°, Distance: 719.5720780918346 km
# STARLINK-4641 at Azimuth: 105.87775162153336°, Altitude: 28.20142836065534°, Distance: 1025.776271385554 km
# STARLINK-4589 at Azimuth: 353.2394223719751°, Altitude: 52.23399509334054°, Distance: 673.8067804961973 km
# STARLINK-4756 at Azimuth: 43.041206027967654°, Altitude: 35.974033808820046°, Distance: 867.4311384935935 km
# STARLINK-4754 at Azimuth: 295.7382398654683°, Altitude: 27.099324000565822°, Distance: 1055.555357777875 km
# STARLINK-5034 at Azimuth: 77.83209926746804°, Altitude: 28.553934580041105°, Distance: 1018.1656633347503 km
# STARLINK-5003 at Azimuth: 255.20640865879147°, Altitude: 48.90742692918068°, Distance: 701.7468988215404 km
# STARLINK-5018 at Azimuth: 255.0775244814966°, Altitude: 48.66407509137387°, Distance: 709.9583727286953 km
# STARLINK-5172 at Azimuth: 55.605133008599026°, Altitude: 20.033871506205532°, Distance: 1283.3721868266364 km
# STARLINK-5210 at Azimuth: 162.57477221991704°, Altitude: 31.382739528233955°, Distance: 950.8183093276158 km
# STARLINK-5623 at Azimuth: 329.4445014939459°, Altitude: 21.186010960251828°, Distance: 1311.0071042633992 km
# STARLINK-5727 at Azimuth: 191.91792441570018°, Altitude: 30.612440410165437°, Distance: 999.307050577481 km
# STARLINK-5487 at Azimuth: 0.1911914930787362°, Altitude: 21.982073881065244°, Distance: 1283.626050587673 km
# STARLINK-5818 at Azimuth: 176.09531151933535°, Altitude: 20.420784808056577°, Distance: 1332.5242321913674 km
# STARLINK-5915 at Azimuth: 134.18436693600287°, Altitude: 21.37756257238798°, Distance: 1266.418365986196 km
# STARLINK-5962 at Azimuth: 171.89641558732984°, Altitude: 23.549299357627966°, Distance: 1191.2093576634984 km
# STARLINK-5771 at Azimuth: 209.59822677235442°, Altitude: 25.125839935360588°, Distance: 1142.798483249147 km
# STARLINK-6350 at Azimuth: 153.63384019198867°, Altitude: 36.72476886427434°, Distance: 881.8808406260115 km
# STARLINK-5049 at Azimuth: 148.14926317958538°, Altitude: 30.878643478006698°, Distance: 994.2301127170616 km
# STARLINK-5503 at Azimuth: 240.22583654954477°, Altitude: 22.163145909120285°, Distance: 1240.0413657724296 km
# STARLINK-30081 at Azimuth: 203.2818332996164°, Altitude: 36.62889516039342°, Distance: 882.2702210556427 km
# STARLINK-30262 at Azimuth: 224.3853049723665°, Altitude: 21.676852013247697°, Distance: 1068.087550391795 km
# STARLINK-30296 at Azimuth: 263.2287959081781°, Altitude: 23.383440480600118°, Distance: 1052.951644770241 km
# STARLINK-30566 at Azimuth: 119.46310897766023°, Altitude: 21.01238120437926°, Distance: 1280.936051209917 km
# STARLINK-30480 at Azimuth: 144.83993110569617°, Altitude: 27.912812722864132°, Distance: 943.542970796136 km
# STARLINK-30595 at Azimuth: 315.56441253285044°, Altitude: 29.623837988199252°, Distance: 896.7083717217105 km
# STARLINK-30803 at Azimuth: 69.25722862772678°, Altitude: 20.206726646308965°, Distance: 1159.849770024612 km
# STARLINK-30829 at Azimuth: 71.32428733788464°, Altitude: 26.124210660571325°, Distance: 977.9974006830018 km
# STARLINK-30888 at Azimuth: 187.9360789353792°, Altitude: 20.5886947313168°, Distance: 1298.665620234278 km
# STARLINK-30928 at Azimuth: 165.00981945051944°, Altitude: 33.75941765398837°, Distance: 934.7731581916545 km
# STARLINK-30995 at Azimuth: 192.92146291034467°, Altitude: 23.13920933589705°, Distance: 1058.1992856917661 km
# STARLINK-31098 at Azimuth: 56.51266048247644°, Altitude: 48.67316318546205°, Distance: 719.6441990766144 km
# STARLINK-31269 at Azimuth: 94.61169517646067°, Altitude: 35.68725289588461°, Distance: 888.6447905624467 km
# STARLINK-31199 at Azimuth: 162.05045482633048°, Altitude: 34.03060063651898°, Distance: 821.0680979009888 km
# STARLINK-31586 at Azimuth: 69.72651193460771°, Altitude: 28.05750219421173°, Distance: 870.1858790183944 km
# STARLINK-31591 at Azimuth: 41.88151800947782°, Altitude: 41.32719036570481°, Distance: 645.183238111872 km
# STARLINK-31523 at Azimuth: 77.798194924581°, Altitude: 21.219140004349775°, Distance: 1053.7658531908962 km
# STARLINK-31634 at Azimuth: 175.64469066003622°, Altitude: 27.94555760073659°, Distance: 864.5790524117446 km
# Tracking satellite: STARLINK-1096
# Satellites inside the FOV: ['STARLINK-1096', 'STARLINK-1100', 'STARLINK-1090', 'STARLINK-1166', 'STARLINK-1150', 'STARLINK-1639', 'STARLINK-1775', 'STARLINK-2361', 'STARLINK-2365', 'STARLINK-2374', 'STARLINK-3297', 'STARLINK-3344', 'STARLINK-3364', 'STARLINK-3182', 'STARLINK-3505', 'STARLINK-4001', 'STARLINK-3994', 'STARLINK-3868', 'STARLINK-4716', 'STARLINK-4589', 'STARLINK-4756', 'STARLINK-5003', 'STARLINK-5018', 'STARLINK-5623', 'STARLINK-5487', 'STARLINK-30595', 'STARLINK-31098', 'STARLINK-31591']
# First entry time: 2024-05-24 20:36:35 (UTC)
# Next pass time: 2024-05-25 16:47:45 (UTC)
# Satellite name: STARLINK-1096
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 166
#     164 print(f"Next pass time: {next_pass_time.utc_strftime('%Y-%m-%d %H:%M:%S (UTC)')}")
#     165 print(f"Satellite name: {selected_sat.name}")
# --> 166 print(f"Satellite info: Azimuth: {az.degrees}°, Altitude: {alt.degrees}°")
#
# NameError: name 'az' is not defined
